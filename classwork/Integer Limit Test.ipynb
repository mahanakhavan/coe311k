# %%
i = 1
i = i+1
print(i)
# Out:
# 2

# %%
i = 1
print(i)
# Out:
# 1

# %%
print(i+0.001)
# Out:
# 1.001

# %%
i + 2**2
# Out:
# 5

# %%
i + 2**-1
# Out:
# 1.5

# %%
i + 2**-50
# Out:
# 1.0000000000000009

# %%
i + 2**-52
# Out:
# 1.0000000000000002

# %%
i+ 2**-53
# Out:
# 1.0
