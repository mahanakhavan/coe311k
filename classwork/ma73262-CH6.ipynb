# %% [markdown]
# ## Jacobi Function

# %%
import numpy as np
def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]

        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
        
    return x, max_iterations

# %% [markdown]
# ## Gauss-Seidel Function

# %%
import numpy as np
def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    
    for k in range(max_iterations):
        x_new = x.copy()
        
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
            
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        
        x = x_new
    return x, max_iterations

# %% [markdown]
# ## Jacobi Example 1

# %%
import time

A = np.array([[10, -1, 2, 0, 0],
[-1, 11, -1, 3, 0],
[2, -1, 10, -1, 0],
[0, 3, -1, 8, -2],
[0, 0, 0, -2, 9]])
b = np.array([14, 30, 26, 25, 37])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100

solution, iterations = jacobi(A, b, x0, tol, max_iterations)

start_time = time.perf_counter()
end_time = time.perf_counter()
elapsed_time = end_time - start_time

print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print("Time taken (seconds):", elapsed_time)
# Out:
# Solution: [1 2 2 3 4]
# Iterations: 1
# Time taken (seconds): 6.51925802230835e-05

# %% [markdown]
# ## Gauss-Seidel Example 1

# %%
A = np.array([[10, -1, 2, 0, 0],
[-1, 11, -1, 3, 0],
[2, -1, 10, -1, 0],
[0, 3, -1, 8, -2],
[0, 0, 0, -2, 9]])
b = np.array([14, 30, 26, 25, 37])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100

solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)

start_time = time.perf_counter()
end_time = time.perf_counter()
elapsed_time = end_time - start_time

print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print("Time taken (seconds):", elapsed_time)
# Out:
# Solution: [1 2 2 3 4]
# Iterations: 2
# Time taken (seconds): 6.054714322090149e-05

# %% [markdown]
# ## Jacobi Example 2

# %%
A = np.array([[1, 2, 3, 0, 0],
[2, 1, 2, 3, 0],
[3, 2, 1, 2, 3],
[0, 3, 2, 1, 2],
[0, 0, 3, 2, 1]], dtype=float)

b = np.array([14, 22, 33, 26, 22], dtype=float)
x0 = np.zeros_like(b, dtype=float)
tol = 1e-6
max_iterations = 100

solution, iterations = jacobi(A, b, x0, tol, max_iterations)

start_time = time.perf_counter()
end_time = time.perf_counter()
elapsed_time = end_time - start_time

print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print("Time taken (seconds):", elapsed_time)
# Out:
# Solution: [-3.43010894e+85 -4.24934579e+85 -5.28966155e+85 -4.24934579e+85
#  -3.43010894e+85]
# Iterations: 100
# Time taken (seconds): 5.354359745979309e-05

# %% [markdown]
# ## Gauss-Seidel Example 2

# %%
A = np.array([
    [1, 2, 3, 0, 0],
    [2, 1, 2, 3, 0],
    [3, 2, 1, 2, 3],
    [0, 3, 2, 1, 2],
    [0, 0, 3, 2, 1]], dtype=float)

b = np.array([14, 22, 33, 26, 22], dtype=float)
x0 = np.zeros_like(b, dtype=float)
tol = 1e-6
max_iterations = 100

solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)

start_time = time.perf_counter()
end_time = time.perf_counter()
elapsed_time = end_time - start_time

print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print("Time taken (seconds):", elapsed_time)
# Out:
# Solution: [-8.70303388e+112  3.37515847e+113 -5.07312279e+113 -1.50300774e+113
#   1.82253839e+114]
# Iterations: 100
# Time taken (seconds): 6.976723670959473e-05

# %% [markdown]
# ### I changed the matrices to floats and it fixed the overflow issue, and I also added a time function I found from searching up on the internet.
